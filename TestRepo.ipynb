# %% [markdown]
# Hello, AIML!

# %%
print("Hello, AIML!")
# Out:
# Hello, AIML!

# %% [markdown]
# A brief history of Artificial Intelligence
# ![A brief history of Artificial Intelligence](AI_History.jpg)
